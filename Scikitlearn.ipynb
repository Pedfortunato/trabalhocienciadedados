# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedfortunato/trabalhocienciadedados/blob/main/Scikitlearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Para visualização de gráficos
# %matplotlib inline
from pylab import *


import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
np.random.seed(9876777)



# Importando Matplotlib e Numpy
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline


# Diâmetros (cm)
Diametros = [[7], [12], [16], [33], [45]]

# Preços (R$)
Precos = [[8], [11], [25], [39], [52]]


plt.figure()
plt.xlabel('Diâmetro(cm)')
plt.ylabel('Preço(R$)')
plt.title('Diâmetro x Preço')
plt.plot(Diametros, Precos, 'k.')
plt.axis([0, 60, 0, 60])
plt.grid(True)
plt.show()



# Importando o módulo de Regressão Linear do scikit-learn
from sklearn.linear_model import LinearRegression


# Preparando os dados de treino

# Vamos chamar de X os dados de diâmetro da Pizza.
X = [[7], [12], [16], [33], [45]]

# Vamos chamar de Y os dados de preço da Pizza.
Y = [[8], [11], [25], [39], [52]]


# Criando o modelo
modelo = LinearRegression()


type(modelo)

sklearn.linear_model._base.LinearRegression

# Treinando o modelo
modelo.fit(X, Y)

LinearRegression()
In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# Coeficientes
print('Coeficiente: \n', modelo.coef_)

# MSE (mean square error)
print("MSE: %.2f" % np.mean((modelo.predict(X) - Y) ** 2))

# Score de variação: 1 representa predição perfeita
print('Score de variação: %.2f' % modelo.score(X, Y))

Coeficiente:
 [[1.20422117]]
MSE: 2.74
Score de variação: 0.99

# Scatter Plot representando a regressão linear
plt.scatter(X, Y,  color = 'black')
plt.plot(X, modelo.predict(X), color = 'blue', linewidth = 3)
plt.xlabel('X')
plt.ylabel('Y')
plt.xticks(())
plt.yticks(())

plt.show()



# Importando os módulos necessários
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
# %matplotlib inline


df_iris = pd.read_csv("iris(1).csv")


# Diâmetros (cm)
Diametros = [[7], [12], [16], [33], [45]]

# Preços (R$)
Precos = [[8], [11], [25], [39], [52]]


plt.figure()
plt.xlabel('Diâmetro(cm)')
plt.ylabel('Preço(R$)')
plt.title('Diâmetro x Preço')
plt.plot(Diametros, Precos, 'k.')
plt.axis([0, 60, 0, 60])
plt.grid(True)
plt.show()



# Importando o módulo de Regressão Linear do scikit-learn
from sklearn.linear_model import LinearRegression


# Preparando os dados de treino

# Vamos chamar de X os dados de diâmetro da Pizza.
X = [[7], [12], [16], [33], [45]]

# Vamos chamar de Y os dados de preço da Pizza.
Y = [[8], [11], [25], [39], [52]]


# Criando o modelo
modelo = LinearRegression()


type(modelo)

sklearn.linear_model._base.LinearRegression

# Treinando o modelo
modelo.fit(X, Y)

LinearRegression()
In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# Scatter Plot representando a regressão linear
plt.scatter(X, Y,  color = 'black')
plt.plot(X, modelo.predict(X), color = 'blue', linewidth = 3)
plt.xlabel('X')
plt.ylabel('Y')
plt.xticks(())
plt.yticks(())

plt.show()
# Out:
#   File "<ipython-input-1-b6ea79b79787>", line 63
#     In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
#        ^
# SyntaxError: invalid syntax
